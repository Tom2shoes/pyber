# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)

# preview of city_data
city_data.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
# preview of ride_data
ride_data.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
# Combine the data into a single dataset
pyber_df = pd.merge(ride_data, city_data, on='city',indicator=True, how='left')

# Display the data table for preview
pyber_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type _merge
# 0             5  Urban   both
# 1            72  Urban   both
# 2            57  Urban   both
# 3            34  Urban   both
# 4            46  Urban   both

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain ride count grouped by city type and city
city_ride_count = pd.DataFrame(pyber_df.groupby(['type', 'city'])['ride_id'].count())
city_ride_count.columns = ['ride count']
city_ride_count.head()
# Out:
#                       ride count
# type  city
# Rural Bradshawfurt            10
#       Garzaport                3
#       Harringtonfort           6
#       Jessicaport              6
#       Lake Jamie               6

# %%
# Obtain fare average grouped by city type and city
city_fare_mean = pd.DataFrame(pyber_df.groupby(['type', 'city'])['fare'].mean())
city_fare_mean.columns = ['average fare']
city_fare_mean.head()
# Out:
#                       average fare
# type  city
# Rural Bradshawfurt       40.064000
#       Garzaport          24.123333
#       Harringtonfort     33.470000
#       Jessicaport        36.013333
#       Lake Jamie         34.358333

# %%
# obtain driver count grouped by city type and city
# using mean here works because the driver count stays constant for each city
driver_count = pd.DataFrame(pyber_df.groupby(['type', 'city'])['driver_count'].mean())
driver_count.columns = ['driver count']
driver_count.head()
# Out:
#                       driver count
# type  city
# Rural Bradshawfurt               7
#       Garzaport                  7
#       Harringtonfort             4
#       Jessicaport                1
#       Lake Jamie                 4

# %%
# Merge the above 3 cells into a single dataframe 
city_type_chart = pd.merge(city_ride_count, city_fare_mean, on=['type', 'city'], how='left')\
                    .merge(driver_count, on=['type', 'city'], how='left')
city_type_chart.head()
# Out:
#                       ride count  average fare  driver count
# type  city
# Rural Bradshawfurt            10     40.064000             7
#       Garzaport                3     24.123333             7
#       Harringtonfort           6     33.470000             4
#       Jessicaport              6     36.013333             1
#       Lake Jamie               6     34.358333             4

# %%
# Build the scatter plots for each city types
rural = plt.scatter(city_type_chart.loc['Rural', 'ride count'], 
                    city_type_chart.loc['Rural', 'average fare'], 
                    color="khaki", label="Rural", 
                    s= 5 * city_type_chart.loc['Rural', 'driver count'],
                    edgecolors="black", alpha=0.7
                   )

suburban = plt.scatter(city_type_chart.loc['Suburban', 'ride count'],
                       city_type_chart.loc['Suburban', 'average fare'], 
                       color="lightblue", label="Suburban",
                       s= 5 * city_type_chart.loc['Suburban', 'driver count'],
                       edgecolors="black", alpha=0.7
                      )

urban = plt.scatter(city_type_chart.loc['Urban', 'ride count'], 
                    city_type_chart.loc['Urban', 'average fare'], 
                    color="coral", label="Urban",
                    s= 5 * city_type_chart.loc['Urban', 'driver count'],
                    edgecolors="black", alpha=0.7
                   )

# Create legend and set size to 30
legend = plt.legend(title="City Types")
legend.legendHandles[0]._sizes = [30]
legend.legendHandles[1]._sizes = [30]
legend.legendHandles[2]._sizes = [30]

# Incorporate the other graph properties
plt.grid()
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")

# Incorporate a text label regarding circle size
plt.text(43, 33, "Note:\nCircle size correlates with driver count per city.")

# Show Figure
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate total fares by city type
rural_fare_sum = pyber_df.loc[pyber_df['type'] == "Rural" , 'fare'].sum()
suburban_fare_sum = pyber_df.loc[pyber_df['type'] == "Suburban" , 'fare'].sum()
urban_fare_sum = pyber_df.loc[pyber_df['type'] == "Urban" , 'fare'].sum()

# Build Pie Chart
labels = ('Rural', 'Suburban', 'Urban')
sizes = (rural_fare_sum, suburban_fare_sum, urban_fare_sum)
explode = (0,0,0.1)
colors = ('khaki','lightblue','coral')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,labels=labels, autopct='%1.1f%%',
        colors=colors,explode=explode, shadow=True, 
        startangle=150)

plt.title("% of Total Fares by City Type")
ax1.axis('equal')

# Save Figure
plt.savefig('total_fares_city_type.png')

# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate rides count by city type
rural_rides_count = pyber_df.loc[pyber_df['type'] == "Rural" , 'type'].count()
suburban_rides_count = pyber_df.loc[pyber_df['type'] == "Suburban" , 'type'].count()
urban_rides_count = pyber_df.loc[pyber_df['type'] == "Urban" , 'type'].count()

# Build Pie Chart
labels = ('Rural', 'Suburban', 'Urban')
sizes = (rural_rides_count, suburban_rides_count, urban_rides_count)
explode = (0,0,0.1)
colors = ('khaki','lightblue','coral')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,labels=labels, autopct='%1.1f%%',
        colors=colors,explode=explode, shadow=True, 
        startangle=150)

plt.title("% of Total Rides by City Type")
ax1.axis('equal')

# Save Figure
plt.savefig('total_rides_city_type.png')

# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver sum by city type
rural_drivers_count = city_data.loc[city_data['type'] == "Rural" , 'driver_count'].sum()
suburban_drivers_count = city_data.loc[city_data['type'] == "Suburban" , 'driver_count'].sum()
urban_drivers_count = city_data.loc[city_data['type'] == "Urban" , 'driver_count'].sum()

# Build Pie Charts
labels = ('Rural', 'Suburban', 'Urban')
sizes = (rural_drivers_count, suburban_drivers_count, urban_drivers_count)
explode = (0,0,0.1)
colors = ('khaki','lightblue','coral')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,labels=labels, autopct='%1.1f%%',
        colors=colors,explode=explode, shadow=True, 
        startangle=150)

plt.title("% of Total Drivers by City Type")
ax1.axis('equal')

# Save Figure
plt.savefig('total_drivers_city_type.png')

# Show Figure
plt.show()
